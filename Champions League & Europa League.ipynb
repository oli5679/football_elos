# %%
import elo
import seaborn as sns

# %%
sns.set_style('white')

# %%
cl_draw = [
        
            ['Barcelona','Liverpool'],
            ['Tottenham','Ajax']
]

# %%
el_draw = [
        ['Arsenal','Valencia'],
        ['Frankfurt','Chelsea'],
]

# %%
#Source http://clubelo.com/
# 10/4/2019

# %%
cl_latest_ratings = {
    'Ajax':1815,
    'Liverpool':2004,
    'Tottenham':1914,
    'Barcelona':2036,
}

# %%
#Source http://clubelo.com/
# 17/4/2019

# %%
el_latest_ratings = {
    'Arsenal':1901,
    'Valencia':1823,
    'Frankfurt':1787,
    'Chelsea':1864,
}

# %%
sim_cl = elo.sim_multiple_tournaments(tree=cl_draw,
                                      elo_dict=cl_latest_ratings)

# %%
ax = elo.plot_counter(plt_data=sim_cl, 
                      title='Champions League winning prob.')

# %%
sim_el = elo.sim_multiple_tournaments(tree=el_draw,
                                      elo_dict=el_latest_ratings)

# %%
ax = elo.plot_counter(plt_data=sim_el, 
                      title='Europa League winning prob.')
